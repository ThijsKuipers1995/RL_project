# %%
from codebase import experiments

# %%
experiments.episode_lengths_q_learning_determinstic()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:04<00:00, 200.82it/s]

# %%
experiments.episode_lengths_double_q_learning_deterministic()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 184.48it/s]

# %%
experiments.episode_lengths_q_learning_stochastic()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5000/5000 [02:36<00:00, 31.95it/s]

# %%
experiments.episode_lengths_double_q_learning_stochastic()
# Out:
#  23%|█████████████████▋                                                            | 1132/5000 [00:44<02:52, 22.46it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2f7b633446da> in <module>
# ----> 1 experiments.episode_lengths_double_q_learning_stochastic()
#
# J:\Jonne\Documents\UvA\AI\RL\RL_project\codebase\experiments.py in episode_lengths_double_q_learning_stochastic(epsilon, num_episodes, n, result_target)
#      45     policy = EpsilonGreedyPolicy(Qt + Qb, epsilon=epsilon)
#      46
# ---> 47     Q, (episode_lengths, R) = double_q_learning(env, policy, Qt, Qb, num_episodes)
#      48     plt.imshow(np.argmax(Q[0], 1).reshape(*SHAPE) % 4)
#      49     cbar = plt.colorbar(ticks=[0,1,2,3])
#
# J:\Jonne\Documents\UvA\AI\RL\RL_project\codebase\models\q_learning.py in double_q_learning(env, policy, Qt, Qb, num_episodes, discount_factor, alpha, random_Q_choice, eps, update_Q_fn, result_target)
#      45         while not done:
#      46             action = policy.sample_action(state)
# ---> 47             old_state, state, reward, done, _ = state, *env.step(action)
#      48
#      49             if Q_choice_fn(i, eps):
#
# J:\Jonne\Documents\UvA\AI\RL\RL_project\codebase\environments\stochasticEnv.py in step(self, a)
#       7     def step(self, a):
#       8         transitions = self.P[self.s][a]
# ----> 9         i = rng.choice(len(transitions), 1, p=[t[0] for t in transitions])[0]
#      10         p, s, r, d = transitions[i]
#      11         self.s = s
#
# KeyboardInterrupt:

# %%
experiments.episode_lengths_q_learning_left_right()
