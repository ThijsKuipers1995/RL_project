# %%
from codebase import experiments

# %%
experiments.gridworld_test()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:07<00:00,  1.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:07<00:00,  1.38it/s]

# %%
experiments.gridworld_test(stochastic=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:09<00:00,  1.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:08<00:00,  1.16it/s]

# %%
experiments.gridworld_test(policy_type="epsilon_greedy", epsilon=0.1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [01:09<00:00,  1.44it/s]
#  32%|█████████████████████████▉                                                       | 32/100 [00:23<00:48,  1.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ca4ab5a82bd7> in <module>
# ----> 1 experiments.gridworld_test(policy_type="epsilon_greedy", epsilon=0.1)
#
# J:\Jonne\Documents\UvA\AI\RL\RL_project\codebase\experiments.py in gridworld_test(num_iters, epsilon, num_episodes, n, result_target, stochastic, policy_type)
#     181         policy = policy_cl(Q1 + Q2, **pol_args)
#     182
# --> 183         (Q1, Q2), (episode_lengths, R, _) = double_q_learning(env, policy, Q1, Q2, num_episodes, verbatim=False, result_target=result_target, update_Q_fn=lambda Qt, Qb: np.maximum(Qt, Qb))
#     184
#     185         lengths_dbl_q[i] = running_mean(episode_lengths, 10)
#
# J:\Jonne\Documents\UvA\AI\RL\RL_project\codebase\models\q_learning.py in double_q_learning(env, policy, Qt, Qb, num_episodes, discount_factor, alpha, random_Q_choice, eps, update_Q_fn, result_target, verbatim)
#      57             action = policy.sample_action(state, env)
#      58             actions.append(action)
# ---> 59             old_state, state, reward, done, _ = state, *env.step(action)
#      60
#      61             if Q_choice_fn(i, eps):
#
# J:\Jonne\Documents\UvA\AI\RL\RL_project\codebase\environments\stochasticEnv.py in step(self, a)
#       7     def step(self, a):
#       8         transitions = self.P[self.s][a]
# ----> 9         i = rng.choice(len(transitions), 1, p=[t[0] for t in transitions])[0]
#      10         p, s, r, d = transitions[i]
#      11         self.s = s
#
# KeyboardInterrupt:

# %%
experiments.gridworld_test(policy_type="epsilon_greedy", epsilon=0.5)

# %%
experiments.gridworld_test(policy_type="epsilon_greedy", stochastic=True, epsilon=0.5)

# %%
experiments.gridworld_test(policy_type="epsilon_greedy", epsilon=0.9)

# %%
experiments.gridworld_test(policy_type="epsilon_greedy", stochastic=True, epsilon=0.9)

# %%
experiments.gridworld_test(policy_type="epsilon_greedy", stochastic=True, epsilon=0.1)

# %%
experiments.gridworld_test(policy_type="softmax")

# %%
experiments.gridworld_test(policy_type="softmax", stochastic=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:29<00:00,  2.09s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:44<00:00,  1.64s/it]

# %%
experiments.gridworld_test(policy_type="softmax", stochastic=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:31<00:00,  2.12s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [01:53<00:00,  1.13s/it]

# %%
experiments.episode_lengths_q_learning_determinstic()

# %%
experiments.episode_lengths_double_q_learning_deterministic()

# %%
experiments.episode_lengths_q_learning_stochastic()

# %%
experiments.episode_lengths_double_q_learning_stochastic()

# %%
# experiments.episode_lengths_q_learning_left_right()

# %%
# experiments.episode_lengths_q_learning_left_right(mu=0.1)

# %%
# experiments.episode_lengths_double_q_learning_left_right()

# %%
# experiments.episode_lengths_double_q_learning_left_right(mu=0.1)

# %%
experiments.ratio_left_right(mu=-0.5, epsilon=1)

# %%
experiments.ratio_left_right(mu=-0.5, epsilon=0.1, policy_type="epsilon_greedy")

# %%
experiments.ratio_left_right(mu=-0.5, epsilon=0.5, policy_type="epsilon_greedy")

# %%
experiments.ratio_left_right(mu=-0.5, epsilon=0.9, policy_type="epsilon_greedy")

# %%
experiments.ratio_left_right(mu=-0.5, policy_type="softmax")

# %%
experiments.ratio_left_right(mu=-0.5, epsilon=1, policy_type='dynamic')

# %%
experiments.ratio_left_right(mu=0.5, epsilon=0.1, policy_type="epsilon_greedy", num_episodes=40000, nr_iters=15)

# %%
experiments.ratio_left_right(mu=0.5, epsilon=0.5, policy_type="epsilon_greedy")

# %%
experiments.ratio_left_right(mu=0.5, epsilon=0.9, policy_type="epsilon_greedy")

# %%
experiments.ratio_left_right(mu=0.5, policy_type="softmax")
# Out:
#   0%|                                                                                         | 0/1000 [00:00<?, ?it/s]
#   2%|█▊                                                                              | 23/1000 [00:01<00:43, 22.54it/s]
#   5%|███▊                                                                            | 47/1000 [00:02<00:41, 22.71it/s]
#   7%|█████▋                                                                          | 71/1000 [00:03<00:40, 22.81it/s]
#   9%|███████▌                                                                        | 94/1000 [00:04<00:39, 22.86it/s]
#  12%|█████████▎                                                                     | 118/1000 [00:05<00:38, 22.93it/s]
#  14%|███████████▏                                                                   | 142/1000 [00:06<00:37, 22.97it/s]
#  17%|█████████████                                                                  | 166/1000 [00:07<00:36, 23.05it/s]
#  19%|██████████████▊                                                                | 188/1000 [00:08<00:35, 22.63it/s]
#  21%|████████████████▋                                                              | 211/1000 [00:09<00:34, 22.57it/s]
#  23%|██████████████████▍                                                            | 234/1000 [00:10<00:34, 22.47it/s]
#  26%|████████████████████▎                                                          | 257/1000 [00:11<00:32, 22.59it/s]
#  32%|█████████████████████████▉                                                       | 32/100 [00:40<00:48,  1.39it/s]
#  30%|███████████████████████▉                                                       | 303/1000 [00:13<00:31, 22.40it/s]
#  33%|█████████████████████████▊                                                     | 327/1000 [00:14<00:29, 22.58it/s]
#  35%|███████████████████████████▋                                                   | 350/1000 [00:15<00:28, 22.69it/s]
#  37%|█████████████████████████████▍                                                 | 373/1000 [00:16<00:27, 22.72it/s]
#  40%|███████████████████████████████▎                                               | 396/1000 [00:17<00:26, 22.71it/s]
#  42%|█████████████████████████████████                                              | 419/1000 [00:18<00:25, 22.75it/s]
#  44%|██████████████████████████████████▉                                            | 442/1000 [00:19<00:24, 22.77it/s]
#  46%|████████████████████████████████████▋                                          | 465/1000 [00:20<00:23, 22.75it/s]
#  49%|██████████████████████████████████████▌                                        | 488/1000 [00:21<00:22, 22.76it/s]
#  51%|████████████████████████████████████████▎                                      | 511/1000 [00:22<00:21, 22.59it/s]
#  53%|██████████████████████████████████████████▏                                    | 534/1000 [00:23<00:20, 22.57it/s]
#  56%|████████████████████████████████████████████                                   | 557/1000 [00:24<00:19, 22.44it/s]
#  58%|█████████████████████████████████████████████▊                                 | 580/1000 [00:25<00:18, 22.28it/s]
#  60%|███████████████████████████████████████████████▋                               | 603/1000 [00:26<00:17, 22.45it/s]
#  63%|█████████████████████████████████████████████████▍                             | 626/1000 [00:27<00:16, 22.51it/s]
#  65%|███████████████████████████████████████████████████▎                           | 649/1000 [00:28<00:15, 22.41it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-950967ebde1a> in <module>
# ----> 1 experiments.ratio_left_right(mu=0.5, policy_type="softmax")
#
# J:\Jonne\Documents\UvA\AI\RL\RL_project\codebase\experiments.py in ratio_left_right(epsilon, num_episodes, mu, num_iters, result_target, policy_type)
#     115         Q, (_, R, actions) = q_learning(env, policy, Q, num_episodes,
#     116                                     verbatim=False, result_target=result_target)
# --> 117         q_rewards[i] = np.array(R)
#     118         q_actions[i] = np.array([action[0] for action in actions])
#     119
#
# KeyboardInterrupt:

# %%
experiments.ratio_left_right(mu=0.5, epsilon=1, policy_type='dynamic')
